# %% [markdown]
# # Нечетное сравнение строк

# %%
import csv
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# c:\Users\Surflay\AppData\Local\Programs\Python\Python310\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
file_cities_csv = "koord_russia.csv"           # Windows-1251
file_cities_csv_utf8 = "koord_russia_utf8.csv" # Utf-8

# %%
with open(file_cities_csv) as f:
    reader = csv.DictReader(f)
    for line in reader:
        print(line)
# Out:
# {'Город;Регион;Федеральный округ;lat;lng': 'Абаза;Хакасия;Сибирский;52', None: ['651657;90', '088572']}
# {'Город;Регион;Федеральный округ;lat;lng': 'Абакан;Хакасия;Сибирский;53', None: ['721152;91', '442387']}
# {'Город;Регион;Федеральный округ;lat;lng': 'Абдулино;Оренбургская область;Приволжский;53', None: ['677839;53', '647263']}
# {'Город;Регион;Федеральный округ;lat;lng': 'Абинск;Краснодарский край;Южный;44', None: ['866256;38', '151163']}
# {'Город;Регион;Федеральный округ;lat;lng': 'Агидель;Башкортостан;Приволжский;55', None: ['899835;53', '92204']}
# {'Город;Регион;Федеральный округ;lat;lng': 'Агрыз;Татарстан;Приволжский;56', None: ['526318;52', '995266']}
# {'Город;Регион;Федеральный округ;lat;lng': 'Адыгейск;Адыгея;Южный;44', None: ['884856;39', '190567']}
# {'Город;Регион;Федеральный округ;lat;lng': 'Азнакаево;Татарстан;Приволжский;54', None: ['859808;53', '074533']}
# ...
